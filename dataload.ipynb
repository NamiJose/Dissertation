# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
#Load data
pop_data = pd.read_csv('ltla/census2021-ts001-ltla_population.csv')
pop_den_data=pd.read_csv('ltla/census2021-ts006-ltla_pop_density.csv')
gen_health_data=pd.read_csv('ltla/census2021-ts037-ltla_gen_health.csv')
gen_health_agestd_data=pd.read_csv('ltla/census2021-ts037asp-ltla_gen_health_agestd.csv')
accom_type_data=pd.read_csv('ltla/census2021-ts044-ltla_accom_type.csv')
car_van_availability_data=pd.read_csv('ltla/census2021-ts045-ltla_car_van_availability.csv')
dist_to_work_data=pd.read_csv('ltla/census2021-ts058-ltla_dist_to_work.csv')
hrs_worked_data=pd.read_csv('ltla/census2021-ts059-ltla_hrs_wrkd.csv')
industry_data=pd.read_csv('ltla/census2021-ts060-ltla_industry.csv')
method_of_wrk_travel_data=pd.read_csv('ltla/census2021-ts061-ltla_method-of_travel_to_work.csv')
ns_sec_data=pd.read_csv('ltla/census2021-ts062-ltla_NS_SEC.csv')
occupation_data=pd.read_csv('ltla/census2021-ts063-ltla_occupation.csv')

# %%
# Remove columns 'column_name1' and 'column_name2'
pop_columns_to_remove = [4,5]
pop_data_fin = pop_data.drop(pop_data.columns[pop_columns_to_remove], axis=1)
# Rename column
column_number = 3 
# Specify the new column name
new_column_name = 'total_population' 
# Rename the column by column number
pop_data_fin.columns.values[column_number] = new_column_name
#pop_data_fin

# %%
pop_den_data_fin=[]
pop_den_data_fin=pop_den_data
# Rename column
column_number = 3 
# Specify the new column name
new_column_name = 'population_density' 
# Rename the column by column number
pop_den_data_fin.columns.values[column_number] = new_column_name

# %%
gen_health_agestd_data_fin=[]
gen_health_agestd_data_fin=gen_health_agestd_data
# Rename column
column_number = 3 
# Specify the new column name
new_column_name = 'VGH' 
# Rename the column by column number
gen_health_agestd_data_fin.columns.values[column_number] = new_column_name

column_number = 4
# Specify the new column name
new_column_name = 'GH' 
# Rename the column by column number
gen_health_agestd_data_fin.columns.values[column_number] = new_column_name

column_number = 5
# Specify the new column name
new_column_name = 'FH' 
# Rename the column by column number
gen_health_agestd_data_fin.columns.values[column_number] = new_column_name

column_number = 6
# Specify the new column name
new_column_name = 'BH' 
# Rename the column by column number
gen_health_agestd_data_fin.columns.values[column_number] = new_column_name

column_number = 7
# Specify the new column name
new_column_name = 'VBH' 
# Rename the column by column number
gen_health_agestd_data_fin.columns.values[column_number] = new_column_name

# %%
car_van_availability_data_fin=car_van_availability_data
column_number = 3
# Specify the new column name
new_column_name = 'Tot_Household_Cnt' 
# Rename the column by column number
car_van_availability_data_fin.columns.values[column_number] = new_column_name

column_number = 4
# Specify the new column name
new_column_name = 'HHCnt_0_CarorVan' 
# Rename the column by column number
car_van_availability_data_fin.columns.values[column_number] = new_column_name

column_number = 5
# Specify the new column name
new_column_name = 'HHCnt_1_CarorVan' 
# Rename the column by column number
car_van_availability_data_fin.columns.values[column_number] = new_column_name

column_number = 6
# Specify the new column name
new_column_name = 'HHCnt_2_CarorVan' 
# Rename the column by column number
car_van_availability_data_fin.columns.values[column_number] = new_column_name

column_number = 7
# Specify the new column name
new_column_name = 'HHCnt_GtorEq3_CarorVan' 
# Rename the column by column number
car_van_availability_data_fin.columns.values[column_number] = new_column_name

# %%
dist_to_work_data_fin=dist_to_work_data
column_number = 3
# Specify the new column name
new_column_name = 'Tot_Rsdnts_inEmplymnt' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 4
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_lt2Km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 5
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq2kmlt5km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 6
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq5kmlt10km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name


column_number = 7
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq10kmlt20km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 8
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq20kmlt30km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 9
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq30kmlt40km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 10
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq40kmlt60km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 11
# Specify the new column name
new_column_name = 'RsdntCnt_wrktrvl_gteq60km' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name


column_number = 12
# Specify the new column name
new_column_name = 'RsdntCnt_wrkfrmhme' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

column_number = 13
# Specify the new column name
new_column_name = 'RsdntCnt_wrkatoffshore' 
# Rename the column by column number
dist_to_work_data_fin.columns.values[column_number] = new_column_name

# %%
hrs_worked_data_fin = hrs_worked_data

column_number = 3
# Specify the new column name
new_column_name = 'Tot_Rsdnts_inEmplymnt' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

column_number = 4
# Specify the new column name
new_column_name = 'Tot_Rsdnts_inPartTime' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name


column_number = 5
# Specify the new column name
new_column_name = 'Rsdnts_ptwrk_lteq15hrs' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

column_number = 6
# Specify the new column name
new_column_name = 'Rsdnts_ptwrk_16to30hrs' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

column_number = 7
# Specify the new column name
new_column_name = 'Tot_Rsdnts_inFullTime' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

column_number = 8
# Specify the new column name
new_column_name = 'Rsdnts_ftwrk_31to48hrs' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

column_number = 9
# Specify the new column name
new_column_name = 'Rsdnts_ftwrk_gteq49hrs' 
# Rename the column by column number
hrs_worked_data_fin.columns.values[column_number] = new_column_name

# %%
industry_data_fin=[]
industry_data_fin = industry_data

new_column_names=list()
new_column_names=[
'date'
,'geography'
,'geography code'
,'Tot_Rsdnts_inEmplymnt'
,'Tot_Rsdnts_inIndsA'
,'Rsdnts_inIndsA01'
,'Rsdnts_inIndsA02'
,'Rsdnts_inIndsA03'
,'Tot_Rsdnts_inIndsB'
,'Rsdnts_inIndsB05'
,'Rsdnts_inIndsB06'
,'Rsdnts_inIndsB07'
,'Rsdnts_inIndsB08'
,'Rsdnts_inIndsB09'
,'Tot_Rsdnts_inIndsC'
,'Rsdnts_inIndsC10'
,'Rsdnts_inIndsC11'
,'Rsdnts_inIndsC12'
,'Rsdnts_inIndsC13'
,'Rsdnts_inIndsC14'
,'Rsdnts_inIndsC15'
,'Rsdnts_inIndsC16'
,'Rsdnts_inIndsC17'
,'Rsdnts_inIndsC18'
,'Rsdnts_inIndsC19'
,'Rsdnts_inIndsC20'
,'Rsdnts_inIndsC21'
,'Rsdnts_inIndsC22'
,'Rsdnts_inIndsC23'
,'Rsdnts_inIndsC24'
,'Rsdnts_inIndsC25'
,'Rsdnts_inIndsC26'
,'Rsdnts_inIndsC27'
,'Rsdnts_inIndsC28'
,'Rsdnts_inIndsC29'
,'Rsdnts_inIndsC30'
,'Rsdnts_inIndsC31'
,'Rsdnts_inIndsC32'
,'Rsdnts_inIndsC33'
,'Tot_Rsdnts_inIndsD'
,'Rsdnts_inIndsD35'
,'Tot_Rsdnts_inIndsE'
,'Rsdnts_inIndsE36'
,'Rsdnts_inIndsE37'
,'Rsdnts_inIndsE38'
,'Rsdnts_inIndsE39'
,'Tot_Rsdnts_inIndsF'
,'Rsdnts_inIndsF414243'
,'Tot_Rsdnts_inIndsG'
,'Rsdnts_inIndsG45'
,'Rsdnts_inIndsG46'
,'Rsdnts_inIndsG47'
,'Rsdnts_inIndsG48'
,'Tot_Rsdnts_inIndsH'
,'Rsdnts_inIndsH49'
,'Rsdnts_inIndsH50'
,'Rsdnts_inIndsH51'
,'Rsdnts_inIndsH52'
,'Rsdnts_inIndsH53'
,'Tot_Rsdnts_inIndsI'
,'Rsdnts_inIndsI55'
,'Rsdnts_inIndsI56'
,'Tot_Rsdnts_inIndsJ'
,'Rsdnts_inIndsJ58'
,'Rsdnts_inIndsJ59'
,'Rsdnts_inIndsJ60'
,'Rsdnts_inIndsJ61'
,'Rsdnts_inIndsJ62'
,'Rsdnts_inIndsJ63'
,'Tot_Rsdnts_inIndsK'
,'Rsdnts_inIndsK64'
,'Rsdnts_inIndsK65'
,'Rsdnts_inIndsK66'
,'Tot_Rsdnts_inIndsL'
,'Rsdnts_inIndsL68'
,'Tot_Rsdnts_inIndsM'
,'Rsdnts_inIndsM69'
,'Rsdnts_inIndsM70'
,'Rsdnts_inIndsM71'
,'Rsdnts_inIndsM72'
,'Rsdnts_inIndsM73'
,'Rsdnts_inIndsM74'
,'Rsdnts_inIndsM75'
,'Tot_Rsdnts_inIndsN'
,'Rsdnts_inIndsN77'
,'Rsdnts_inIndsN78'
,'Rsdnts_inIndsN79'
,'Rsdnts_inIndsN80'
,'Rsdnts_inIndsN81'
,'Rsdnts_inIndsN82'
,'Tot_Rsdnts_inIndsO'
,'Rsdnts_inIndsO84'
,'Tot_Rsdnts_inIndsP'
,'Rsdnts_inIndsP85'
,'Tot_Rsdnts_inIndsQ'
,'Rsdnts_inIndsQ86'
,'Rsdnts_inIndsQ87'
,'Rsdnts_inIndsQ88'
,'Tot_Rsdnts_inIndsRSTUOther'
,'Rsdnts_inIndRSTUOther90'
,'Rsdnts_inIndRSTUOther91'
,'Rsdnts_inIndRSTUOther92'
,'Rsdnts_inIndRSTUOther93'
,'Rsdnts_inIndRSTUOther94'
,'Rsdnts_inIndRSTUOther95'
,'Rsdnts_inIndRSTUOther96'
,'Rsdnts_inIndRSTUOther97'
,'Rsdnts_inIndRSTUOther98'
,'Rsdnts_inIndRSTUOther99'

]

column_mapping = dict(zip(industry_data_fin.columns, new_column_names))
industry_data_fin.rename(columns=column_mapping, inplace=True)

# %%
method_of_wrk_travel_data_fin=[]
method_of_wrk_travel_data_fin = method_of_wrk_travel_data

new_column_names=list()
new_column_names=[
    'date'
,'geography'
,'geography code'
,'Tot_Rsdnts_inEmplymnt'
,'RsdntsCnt_wfh'
,'RsdntsCnt_undgrndmetro_lightrail_tram'
,'RsdntsCnt_train'
,'RsdntsCnt_bus_minibus_coach'
,'RsdntsCnt_taxi'
,'RsdntsCnt_motorcycle_moped_scooter'
,'RsdntsCnt_driving_carorvan'
,'RsdntsCnt_passenger_incarorvan'
,'RsdntsCnt_bicycle'
,'RsdntsCnt_onfoot'
,'RsdntsCnt_other'
]
column_mapping = dict(zip(method_of_wrk_travel_data.columns, new_column_names))
method_of_wrk_travel_data_fin.rename(columns=column_mapping, inplace=True)

# %%
ns_sec_data_fin=[]
ns_sec_data_fin = ns_sec_data

new_column_names=list()
new_column_names=[
    'date'
,'geography'
,'geography code'
,'Tot_Rsdnts'
,'RsdntsCnt_L1L2L3'
,'RsdntsCnt_L4L5L6'
,'RsdntsCnt_L7'
,'RsdntsCnt_L8L9'
,'RsdntsCnt_L10L11'
,'RsdntsCnt_L12'
,'RsdntsCnt_L13'
,'RsdntsCnt_L14'
,'RsdntsCnt_L15'
]
column_mapping = dict(zip(ns_sec_data.columns, new_column_names))
ns_sec_data_fin.rename(columns=column_mapping, inplace=True)

# %%
occupation_data_fin=[]
occupation_data_fin = occupation_data

new_column_names=list()
new_column_names=[
    'date'
,'geography'
,'geography code'
,'Tot_Rsdnts_inEmplymnt'
,'RsdntsCnt_Occupation1'
,'RsdntsCnt_Occupation2'
,'RsdntsCnt_Occupation3'
,'RsdntsCnt_Occupation4'
,'RsdntsCnt_Occupation5'
,'RsdntsCnt_Occupation6'
,'RsdntsCnt_Occupation7'
,'RsdntsCnt_Occupation8'
,'RsdntsCnt_Occupation9'
]
column_mapping = dict(zip(occupation_data.columns, new_column_names))
occupation_data_fin.rename(columns=column_mapping, inplace=True)
